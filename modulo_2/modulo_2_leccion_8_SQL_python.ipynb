# %%
import mysql.connector
from mysql.connector import errorcode
import pandas as pd

# %%
try:
    cnx = mysql.connector.connect(user= 'root', password='040394', host='127.0.0.1', database = 'information_schema')
    print("Conexión establecida con éxito")
except mysql.connector.Error as err:
    print(f"Error al conectar con MySQL: {err}")
    
mycursor = cnx.cursor()

query = """
SELECT COLUMN_NAME
FROM COLUMNS
WHERE TABLE_SCHEMA = 'northwind'
  AND TABLE_NAME = 'customers';
"""
mycursor.execute(query)
columnas = mycursor.fetchall()
for columna in columnas:
    print(columna[0])
mycursor.close()
cnx.close()
# Out:
# Conexión establecida con éxito
# CustomerID
# CompanyName
# ContactName
# ContactTitle
# Address
# City
# Region
# PostalCode
# Country
# Phone
# Fax

# %%
try:
    cnx = mysql.connector.connect(user= 'root', password='040394', host='127.0.0.1', database = 'northwind')
    print("Conexión establecida con éxito")
except mysql.connector.Error as err:
    print(f"Error al conectar con MySQL: {err}")
# Out:
# Conexión establecida con éxito

# %%
mycursor = cnx.cursor()
query = "SELECT * FROM customers WHERE city IN ('London', 'Seattle')"
mycursor.execute(query)

resultado = mycursor.fetchall()
print(resultado)
# Out:
# [('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'), ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None), ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Sales Representative', 'Berkeley Gardens 12  Brewery', 'London', None, 'WX1 6LT', 'UK', '(171) 555-2282', '(171) 555-9199'), ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', None, 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373'), ('NORTS', 'North/South', 'Simon Crowther', 'Sales Associate', 'South House 300 Queensbridge', 'London', None, 'SW7 1RZ', 'UK', '(171) 555-7733', '(171) 555-2530'), ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646'), ('WHITC', 'White Clover Markets', 'Karl Jab
# ...

# %%
df = pd.DataFrame(resultado, columns = ['CustomerID','CompanyName','ContactName','ContactTitle','Address','City','Region','PostalCode','Country','Phone','Fax'])

# %%
df
# Out:
#   CustomerID            CompanyName        ContactName          ContactTitle  \
# 0      AROUT        Around the Horn       Thomas Hardy  Sales Representative
# 1      BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 2      CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
# 3      EASTC     Eastern Connection          Ann Devon           Sales Agent
# 4      NORTS            North/South     Simon Crowther       Sales Associate
# 5      SEVES     Seven Seas Imports         Hari Kumar         Sales Manager
# 6      WHITC   White Clover Markets     Karl Jablonski                 Owner
#
#                         Address     City Region PostalCode Country  \
# 0               120 Hanover Sq.   London   None    WA1 1DP      UK
# 1             Fauntleroy Circus   London   None    EC2 5NT      UK
# 2  Berkeley Gardens 12  Brewery   London   None    WX1 6LT      UK
# 3                35 King George   London   None    WX3 6FW      UK
# ...

# %%
query = "SELECT * FROM customers"
mycursor.execute(query)

resultado2= mycursor.fetchall()
print(resultado2)
# Out:
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545'), ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitucin 2222', 'Mxico D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'), ('ANTON', 'Antonio Moreno Taquera', 'Antonio Moreno', 'Owner', 'Mataderos  2312', 'Mxico D.F.', None, '05023', 'Mexico', '(5) 555-3932', None), ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'), ('BERGS', 'Berglunds snabbkp', 'Christina Berglund', 'Order Administrator', 'Berguvsvgen  8', 'Lule', None, 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67'), ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Sales Representative', 'Forsterstr. 57', 'Mannheim', None, '68306', 'Germany', '0621-08460', '0621-08924'), ('BLONP', 'Blondesddsl pre et fils',
# ...

# %%
df2 = pd.DataFrame(resultado2, columns = ['CustomerID','CompanyName','ContactName','ContactTitle','Address','City','Region','PostalCode','Country','Phone','Fax'])

# %%
df2
# Out:
#    CustomerID                         CompanyName              ContactName  \
# 0       ALFKI                 Alfreds Futterkiste             Maria Anders
# 1       ANATR  Ana Trujillo Emparedados y helados             Ana Trujillo
# 2       ANTON              Antonio Moreno Taquera           Antonio Moreno
# 3       AROUT                     Around the Horn             Thomas Hardy
# 4       BERGS                   Berglunds snabbkp       Christina Berglund
# ..        ...                                 ...                      ...
# 88      WARTH                      Wartian Herkku         Pirkko Koskitalo
# 89      WELLI              Wellington Importadora            Paula Parente
# 90      WHITC                White Clover Markets           Karl Jablonski
# 91      WILMK                         Wilman Kala          Matti Karttunen
# 92      WOLZA                      Wolski  Zajazd  Zbyszek Piestrzeniewicz
#
# ...

# %%
df2.head(10)
# Out:
#   CustomerID                         CompanyName         ContactName  \
# 0      ALFKI                 Alfreds Futterkiste        Maria Anders
# 1      ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2      ANTON              Antonio Moreno Taquera      Antonio Moreno
# 3      AROUT                     Around the Horn        Thomas Hardy
# 4      BERGS                   Berglunds snabbkp  Christina Berglund
# 5      BLAUS             Blauer See Delikatessen          Hanna Moos
# 6      BLONP             Blondesddsl pre et fils    Frdrique Citeaux
# 7      BOLID            Blido Comidas preparadas        Martn Sommer
# 8      BONAP                            Bon app'    Laurence Lebihan
# 9      BOTTM               Bottom-Dollar Markets   Elizabeth Lincoln
#
#            ContactTitle                       Address        City Region  \
# 0  Sales Representative                 Obere Str. 57      Berlin   None
# ...

# %%
df2.tail(10)
# Out:
#    CustomerID                CompanyName              ContactName  \
# 83      Val2                          IT                     Val2
# 84      VALON                         IT               Valon Hoti
# 85      VICTE       Victuailles en stock             Mary Saveley
# 86      VINET  Vins et alcools Chevalier             Paul Henriot
# 87      WANDK          Die Wandernde Kuh               Rita Mller
# 88      WARTH             Wartian Herkku         Pirkko Koskitalo
# 89      WELLI     Wellington Importadora            Paula Parente
# 90      WHITC       White Clover Markets           Karl Jablonski
# 91      WILMK                Wilman Kala          Matti Karttunen
# 92      WOLZA             Wolski  Zajazd  Zbyszek Piestrzeniewicz
#
#                  ContactTitle                      Address       City Region  \
# 83                         IT                         None       None   None
# 84                         IT                         None       None   None
# ...

# %%
df2.sample(5)
# Out:
#    CustomerID               CompanyName       ContactName        ContactTitle  \
# 47      LONEP  Lonesome Pine Restaurant       Fran Wilson       Sales Manager
# 75      SUPRD            Suprmes dlices  Pascale Cartrain  Accounting Manager
# 29      GODOS        Godos Cocina Tpica  Jos Pedro Freyre       Sales Manager
# 19      ERNSH              Ernst Handel     Roland Mendel       Sales Manager
# 32      GROSR      GROSELLA-Restaurante    Manuel Pereira               Owner
#
#                      Address       City Region PostalCode    Country  \
# 47        89 Chiaroscuro Rd.   Portland     OR      97219        USA
# 75      Boulevard Tirou, 255  Charleroi   None     B-6000    Belgium
# 29             C/ Romero, 33    Sevilla   None      41101      Spain
# 19              Kirchgasse 6       Graz   None       8010    Austria
# 32  5 Ave. Los Palos Grandes    Caracas     DF       1081  Venezuela
#
#                 Phone                Fax
# ...

# %%
df2.isnull()
# Out:
#     CustomerID  CompanyName  ContactName  ContactTitle  Address   City  \
# 0        False        False        False         False    False  False
# 1        False        False        False         False    False  False
# 2        False        False        False         False    False  False
# 3        False        False        False         False    False  False
# 4        False        False        False         False    False  False
# ..         ...          ...          ...           ...      ...    ...
# 88       False        False        False         False    False  False
# 89       False        False        False         False    False  False
# 90       False        False        False         False    False  False
# 91       False        False        False         False    False  False
# 92       False        False        False         False    False  False
#
#     Region  PostalCode  Country  Phone    Fax
# 0     True       False    False  False  False
# ...

# %%
df2.describe()
# Out:
#        CustomerID CompanyName   ContactName          ContactTitle  \
# count          93          93            93                    93
# unique         93          92            93                    13
# top         ALFKI          IT  Maria Anders  Sales Representative
# freq            1           2             1                    17
#
#               Address    City Region PostalCode Country        Phone  \
# count              91      91     31         90      91           91
# unique             91      69     18         86      21           91
# top     Obere Str. 57  London     SP       1010     USA  030-0074321
# freq                1       6      6          3      13            1
#
#                 Fax
# count            69
# unique           69
# top     030-0076545
# freq              1

# %%
df.columns
# Out:
# Index(['CustomerID', 'CompanyName', 'ContactName', 'ContactTitle', 'Address',
#        'City', 'Region', 'PostalCode', 'Country', 'Phone', 'Fax'],
#       dtype='object')
