# %%
import requests
import pandas as pd

# %%
url_git = "https://api.github.com/users/Narciandi90"
resultados_git = requests.get(url_git)

# %%
resultados_git.status_code
# Out:
# 200

# %%
resultados_git.reason
# Out:
# 'OK'

# %%
resultados_git.json()

# %%
datos_api = resultados_git.json()

# %%
datos_api

# %%
url = "https://api.github.com/users/Mariagranero"
resultados_git2 = requests.get("https://api.github.com/users/Mariagranero")

# %%
resultados_git2.status_code
# Out:
# 200

# %%
resultados_git2.json()

# %%
datos_api2 = resultados_git2.json()

# %%
datos_api2

# %%
#2. API Starwars
#Es una API abierta, por lo que no hace falta autenticación
#Método HTTP : GET
'''Búsqueda de información: films string -- The URL root for Film resources
people string -- The URL root for People resources
planets string -- The URL root for Planet resources
species string -- The URL root for Species resources
starships string -- The URL root for Starships resources
vehicles string -- The URL root for Vehicles resources
                             /people/ --  get all the people resources
                            /people/:id/ -- get a specific people resource'''

url_base = "https://swapi.py4e.com/api/"

# %%
url_personaje = "https://swapi.py4e.com/api/people/"
personajes = requests.get(url_personaje)

# %%
personajes
# Out:
# <Response [200]>

# %%
datos_sw = personajes.json()

# %%
datos_sw.keys()
# Out:
# dict_keys(['count', 'next', 'previous', 'results'])

# %%
url_luke = "https://swapi.py4e.com/api/people/1"
datos_luke = requests.get(url_luke)

# %%
datos_luke.json()
# Out:
# {'name': 'Luke Skywalker',
#  'height': '172',
#  'mass': '77',
#  'hair_color': 'blond',
#  'skin_color': 'fair',
#  'eye_color': 'blue',
#  'birth_year': '19BBY',
#  'gender': 'male',
#  'homeworld': 'https://swapi.py4e.com/api/planets/1/',
#  'films': ['https://swapi.py4e.com/api/films/1/',
#   'https://swapi.py4e.com/api/films/2/',
#   'https://swapi.py4e.com/api/films/3/',
#   'https://swapi.py4e.com/api/films/6/',
#   'https://swapi.py4e.com/api/films/7/'],
#  'species': ['https://swapi.py4e.com/api/species/1/'],
#  'vehicles': ['https://swapi.py4e.com/api/vehicles/14/',
#   'https://swapi.py4e.com/api/vehicles/30/'],
#  'starships': ['https://swapi.py4e.com/api/starships/12/',
#   'https://swapi.py4e.com/api/starships/22/'],
#  'created': '2014-12-09T13:50:51.644000Z',
#  'edited': '2014-12-20T21:17:56.891000Z',
#  'url': 'https://swapi.py4e.com/api/people/1/'}

# %%
url_sorpresa = "https://swapi.py4e.com/api/people/2"
datos_sorpresa = requests.get(url_sorpresa)
datos_sorpresa.json()

# %%
url = "https://swapi.py4e.com/api/people/?search=Luke Skywalker"

# %%
respuesta = requests.get(url)

# %%
respuesta.json()
# Out:
# {'count': 1,
#  'next': None,
#  'previous': None,
#  'results': [{'name': 'Luke Skywalker',
#    'height': '172',
#    'mass': '77',
#    'hair_color': 'blond',
#    'skin_color': 'fair',
#    'eye_color': 'blue',
#    'birth_year': '19BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.py4e.com/api/planets/1/',
#    'films': ['https://swapi.py4e.com/api/films/1/',
#     'https://swapi.py4e.com/api/films/2/',
#     'https://swapi.py4e.com/api/films/3/',
#     'https://swapi.py4e.com/api/films/6/',
#     'https://swapi.py4e.com/api/films/7/'],
#    'species': ['https://swapi.py4e.com/api/species/1/'],
#    'vehicles': ['https://swapi.py4e.com/api/vehicles/14/',
#     'https://swapi.py4e.com/api/vehicles/30/'],
#    'starships': ['https://swapi.py4e.com/api/starships/12/',
#     'https://swapi.py4e.com/api/starships/22/'],
#    'created': '2014-12-09T13:50:51.644000Z',
#    'edited': '2014-12-20T21:17:56.891000Z',
#    'url': 'https://swapi.py4e.com/api/people/1/'}]}
