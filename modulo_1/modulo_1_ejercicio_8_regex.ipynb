# %% [markdown]
# Validar un número de teléfono.
#
# Descripción: Verificar si una cadena representa un número de teléfono válido en el formato (XXX) XXX-XXXX.
#
# Probad para cada uno de los teléfonos que tenemos en la siguiente lista:
# telefonos = ["(123) 456-7890", "178 1890-733", "(555) 238-1987", "(123) 4560-7890", "(ABC) 098-1111"]

# %%
import re

telefonos = ["(123) 456-7890", "178 1890-733", "(555) 238-1987", "(123) 4560-7890", "(ABC) 098-1111"]

# %%
patron_numero = r"^\(\d{3}\)\s\d{3}-\d{4}$"

for telefono in telefonos:
    if re.findall(patron_numero, telefono):
        print("es valido")
    else:
        print("no es valido")
# Out:
# es valido
# no es valido
# es valido
# no es valido
# no es valido

# %% [markdown]
# Buscar todas las direcciones de correo electrónico en un texto.
#
# Descripción: Encontrar todas las direcciones de correo electrónico presentes en una cadena de texto.
#
# Probad con el siguiente string:
#
#
# Copy
# texto = "Mi correo es user@example.com. Contacta conmigo en john.doe@email.com"

# %%
texto = "Mi correo es user@example.com. Contacta conmigo en john.doe@email.com"

# %%
correos_electronicos = "[\w\d]+@(example|email)\.(com|es)"

if re.findall(correos_electronicos, texto):
    print("correo encontrado")
else: 
    print("corrreo no encontrado")
# Out:
# correo encontrado

# %%
correos = re.findall(correos_electronicos, texto)

# %%
print(correos)
# Out:
# [('example', 'com'), ('email', 'com')]
